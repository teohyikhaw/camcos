# %% [markdown]
# Read in the data and import the packages

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from data_personal_example import transaction_data_file, large_pre_gas_prices_file, \
suite_spot_txn, post_eip_large_blocks, block_data_file

pre_eip=pd.read_csv(large_pre_gas_prices_file)
post_eip_blx=pd.read_csv(post_eip_large_blocks)
post_eip_data_1_txn=pd.read_csv(transaction_data_file)
post_eip_data_1_blx=pd.read_csv(block_data_file)

# %% [markdown]
# First we will try to ascertain the distribution of the pre-EIP data.

# %%
display(pre_eip)




pre_gas_price=list(pre_eip.gas_price)

my_up=np.percentile(pre_gas_price,90)
my_lo=np.percentile(pre_gas_price,10)

pre_gas_price=[x for x in pre_gas_price if (x < my_up) & (x > my_lo)]


fig = plt.figure()
ax = plt.axes()


my_mean=np.mean(pre_gas_price)
my_var=np.var(pre_gas_price)



plt.hist(pre_gas_price)
ax.set_title('Pre Eip Gas Price')
print(my_mean,my_var)



#observations
#variance-1.4189931621311085e+21
#mean-165103890667.35025



my_p_data=np.random.poisson(my_mean,len(pre_gas_price))

fig2 = plt.figure()
ax2 = plt.axes()

plt.hist(my_p_data)
ax2.set_title('Truly Poisson data of Same Mean')
print(np.mean(my_p_data),np.var(my_p_data))
# Out:
#                                                       hash  block_number  \
# 0        0xc9d37faf9270c0aa1a553d4e53777cf1617a606d8a26...      12111333
# 1        0xceeee703a7638bfa1eaa0c3d97f31fe211dfb77915e6...      12111413
# 2        0x87007e41f34e2c1ea51fe9ff5bde4a039c70f2a218fe...      12111458
# 3        0x497a2de3a8a8a2799ead2bb558ba072cbb50c1f2ab8a...      12111280
# 4        0x548aa6b360f2b81f0ed437b35af5405dfce857069e71...      12111328
# ...                                                    ...           ...
# 6264787  0xac03a458748d87b1e03732c7a60f13d3f6278e2dfb84...      12088722
# 6264788  0xa10fa129bc83a7d7b85391b7c85ae579b3ab59ef6fd0...      12088822
# 6264789  0xa43bb8f1b1d77b3f9770311998bc667e4e393e022021...      12085526
# 6264790  0x5a90c80b066cd7577c71ee1e891353535d6e5f16f75c...      12087380
# 6264791  0x1ff9ec12cf7037fe6d753309e2baf7334d4b83f5dda8...      12086470
#
#                  block_timestamp  receipt_gas_used     gas_price
# 0        2021-03-26 00:16:51 UTC             45764  129000000000
# 1        2021-03-26 00:33:17 UTC             36601  168000000000
# 2        2021-03-26 00:42:19 UTC             21000  174000000000
# 3        2021-03-26 00:06:07 UTC            154315  168211840178
# 4        2021-03-26 00:15:32 UTC             21000  154000000000
# ...                          ...               ...           ...
# 6264787  2021-03-22 12:53:38 UTC             21000  165000000000
# 6264788  2021-03-22 13:15:19 UTC             21000  213000000000
# 6264789  2021-03-22 00:58:55 UTC            112866  181000000000
# 6264790  2021-03-22 07:54:46 UTC             21000    6000000000
# 6264791  2021-03-22 04:33:07 UTC            124024  122000000000
#
# [6264792 rows x 5 columns]
# 165103890667.35025 1.4189931621311085e+21
# 165103890415.1018 165049812681.72952

# %% [markdown]
# Clearly the data is opperating substantially differently than a poisson r.v of the same mean. Furthermore, in the data, the mean and variance are substantially different, which should not be the case for truly poisson distributed data. Fuyrthermore, poisson data has the property of being able to be approximated by the binomial distribution for large values of n; therefore, like the binomial distribution, it will converge into the shape of a bell. curve for large values of n, clearly not meeting the requirments of our data

# %% [markdown]
# This next section is to determine where the spikes occur in the base fee of our dataset. plotting the data we can see that...

# %%
display(post_eip_blx)
post_eip_blx=post_eip_blx.sort_values(by=['number'])
display(post_eip_blx)


my_number=list(range(len(post_eip_blx.number)))
real_blx=post_eip_blx.number
my_base_fee=list(post_eip_blx.base_fee_per_gas)


fig = plt.figure()
ax = plt.axes()

ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y',colors='white')
ax.title.set_color('white')
plt.plot(my_number,my_base_fee)

print(real_blx[0],real_blx[650],real_blx[1000],real_blx[6500],real_blx[8000], \
      real_blx[10000])

print(real_blx[750]>real_blx[1000])

#real_blx[]


#6500-8000
#650-1000
post_eip_blx.iloc[10000]
#real_blx[800]>real_blx[1000]
# Out:
#           number    size  gas_limit  gas_used   timestamp  base_fee_per_gas
# 0       12965400   52195   27767214   8026699  1628172530      100260964379
# 1       12965401  133741   27740099  24776018  1628172535       94973980561
# 2       12965402    4899   27713011   1376999  1628172548      104308692426
# 3       12965403   91889   27740073  22128780  1628172552       92565823707
# 4       12965404  158870   27712985  27706025  1628172557       99455472742
# ...          ...     ...        ...       ...         ...               ...
# 249996  13215345     537   30000000         0  1631508474       49366304652
# 249997  13215346  121843   30000000  29997391  1631508491       43195516571
# 249998  13215347  118647   30000000  29985901  1631508494       48594016999
# 249999  13215348  108145   30000000  29925154  1631508521       54662559731
# 250000  13215349  101598   30029295   8500558  1631508528       61461285747
#
# [250001 rows x 6 columns]
#           number    size  gas_limit  gas_used   timestamp  base_fee_per_gas
# 0       12965400   52195   27767214   8026699  1628172530      100260964379
# 1       12965401  133741   27740099  24776018  1628172535       94973980561
# 2       12965402    4899   27713011   1376999  1628172548      104308692426
# 3       12965403   91889   27740073  22128780  1628172552       92565823707
# 4       12965404  158870   27712985  27706025  1628172557       99455472742
# ...          ...     ...        ...       ...         ...               ...
# 249896  13215396   87214   30058591  22161127  1631509216       56944495762
# 249897  13215397   49453   30029238   9520510  1631509221       60322220541
# 249898  13215398  144226   30000000  29989644  1631509229       57563102455
# 249899  13215399     534   30000000         0  1631509265       64753522566
# 249900  13215400  110031   30000000  29979151  1631509266       56659332246
#
# [250001 rows x 6 columns]
# 12965400 12966350 12966100 12972100 12973300 12975500
# True
# number                 12975400
# size                       6493
# gas_limit              30234963
# gas_used                1861420
# timestamp            1628305855
# base_fee_per_gas    35921314625
# Name: 11300, dtype: int64

# %% [markdown]
# The results seem to indicate that the most severe spikes in the first 10000 observations are from 12966350-12966100, and 12972100-12973300. When extracting data from the block, I'm gonna want 12965400 through 12975500

# %% [markdown]
# Graphs on request of Kieth

# %%
my_number=list(range(len(post_eip_blx.number)))
real_blx=post_eip_blx.number
my_gas_used=list(post_eip_blx.gas_used)




fig = plt.figure()
ax = plt.axes()

ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y',colors='white')
ax.title.set_color('white')
plt.plot(my_number[0:1000],my_gas_used[0:1000])


fig2 = plt.figure()
ax2 = plt.axes()

ax2.xaxis.label.set_color('white')
ax2.yaxis.label.set_color('white')
ax2.tick_params(axis='x', colors='white')
ax2.tick_params(axis='y',colors='white')
ax2.title.set_color('white')
plt.plot(my_number[0:500],my_gas_used[0:500])


fig3 = plt.figure()
ax3 = plt.axes()

ax3.xaxis.label.set_color('white')
ax3.yaxis.label.set_color('white')
ax3.tick_params(axis='x', colors='white')
ax3.tick_params(axis='y',colors='white')
ax3.title.set_color('white')
plt.plot(my_number[0:250],my_gas_used[0:250])




#print(real_blx[0],real_blx[10000])

# %% [markdown]
# Dr. Zhang question: how many of the transactions are EIP 1559?

# %%
##Question;how many of the transactions are post EIP? 
##first in day 1


display(post_eip_data_1_txn)


day_1_result=len(post_eip_data_1_txn[post_eip_data_1_txn.transaction_type == 2]) \
            / len(post_eip_data_1_txn)
#display(post_eip_data_1_blx)
print('in the first day we get ' + str(day_1_result))
##Late October (27th), again about a 24 hours worth, 13500000-13507000
# Out:
#                                                      hash  block_number  \
# 0       0xc238b942427f549c1abd0d847d24e5be7c927f06f124...      12965400
# 1       0x5ec22214a5800b9c168c5d729be6c51ba11d10c6b3fa...      12965400
# 2       0xaef08e8e460d7c353677b307eccd92670328f05ee41d...      12965400
# 3       0xeae92402433d0d51eb214c7103e73a28a3b976b51ad8...      12965400
# 4       0x66f3f570c83c79cd8c76123f48c8875c822200e562f1...      12965400
# ...                                                   ...           ...
# 884195  0xfe1736a3ff4281e8857a276f7d0dbcdbec7af24a06ff...      12969999
# 884196  0x894de61ac24f1d741e139e12cfaeaa3b931360383c9a...      12969999
# 884197  0xcb5bc90e32f2168ccf2252c7d1eab7151e53b2ac3bd4...      12969999
# 884198  0x5a3d9e436d55893e7841f119de800db953effd148db5...      12969999
# 884199  0xcfbda200e01cdf3354ef975980d582a114d4afb0d4e3...      12969999
#
#                value     gas     gas_price  max_fee_per_gas  \
# 0       0.000000e+00  250000  845636987920              NaN
# 1       0.000000e+00  806541  499000000000              NaN
# 2       0.000000e+00  750000  138641981761              NaN
# 3       0.000000e+00  400000  137641981761              NaN
# 4       0.000000e+00  400000  137641981761              NaN
# ...              ...     ...           ...              ...
# 884195  0.000000e+00  211665   29000000000              NaN
# 884196  1.151710e+17   21000   29000000000              NaN
# 884197  0.000000e+00   66151   29000000000              NaN
# 884198  3.100000e+16  215887   29000000000              NaN
# 884199  8.779940e+15   21000   29000000000              NaN
#
#         max_priority_fee_per_gas  transaction_type  gas_used
# 0                            NaN                 0    151568
# 1                            NaN                 0    566726
# 2                            NaN                 0    181092
# 3                            NaN                 0    196184
# 4                            NaN                 0    184277
# ...                          ...               ...       ...
# 884195                       NaN                 0    211665
# 884196                       NaN                 0     21000
# 884197                       NaN                 0     65613
# 884198                       NaN                 0    163754
# 884199                       NaN                 0     21000
#
# [884200 rows x 9 columns]
# in the first day we get 0.04516285908165574

# %% [markdown]
# Another thing I wanna do is get a proxy for demand by using the number of transactions within the block at any given time of day; To do this I wanna add number of transactions per block into the dataset for a good chunk of pre and post EIP data to get me a good model.

# %%
display(pre_eip)


my_pre_eip_blocks=list(set(pre_eip.block_number))

my_txn_number=[]

for i in my_pre_eip_blocks:
    my_txn_number.append(len(pre_eip[pre_eip.block_number == i]))
    
pre_eip_txn_number=pd.DataFrame({'blocks':my_pre_eip_blocks,'transaction_number':my_txn_number})
display(pre_eip_txn_number)
# Out:
#                                                       hash  block_number  \
# 0        0xc9d37faf9270c0aa1a553d4e53777cf1617a606d8a26...      12111333
# 1        0xceeee703a7638bfa1eaa0c3d97f31fe211dfb77915e6...      12111413
# 2        0x87007e41f34e2c1ea51fe9ff5bde4a039c70f2a218fe...      12111458
# 3        0x497a2de3a8a8a2799ead2bb558ba072cbb50c1f2ab8a...      12111280
# 4        0x548aa6b360f2b81f0ed437b35af5405dfce857069e71...      12111328
# ...                                                    ...           ...
# 6264787  0xac03a458748d87b1e03732c7a60f13d3f6278e2dfb84...      12088722
# 6264788  0xa10fa129bc83a7d7b85391b7c85ae579b3ab59ef6fd0...      12088822
# 6264789  0xa43bb8f1b1d77b3f9770311998bc667e4e393e022021...      12085526
# 6264790  0x5a90c80b066cd7577c71ee1e891353535d6e5f16f75c...      12087380
# 6264791  0x1ff9ec12cf7037fe6d753309e2baf7334d4b83f5dda8...      12086470
#
#                  block_timestamp  receipt_gas_used     gas_price
# 0        2021-03-26 00:16:51 UTC             45764  129000000000
# 1        2021-03-26 00:33:17 UTC             36601  168000000000
# 2        2021-03-26 00:42:19 UTC             21000  174000000000
# 3        2021-03-26 00:06:07 UTC            154315  168211840178
# 4        2021-03-26 00:15:32 UTC             21000  154000000000
# ...                          ...               ...           ...
# 6264787  2021-03-22 12:53:38 UTC             21000  165000000000
# 6264788  2021-03-22 13:15:19 UTC             21000  213000000000
# 6264789  2021-03-22 00:58:55 UTC            112866  181000000000
# 6264790  2021-03-22 07:54:46 UTC             21000    6000000000
# 6264791  2021-03-22 04:33:07 UTC            124024  122000000000
#
# [6264792 rows x 5 columns]
#          blocks  transaction_number
# 0      12085254                 131
# 1      12085255                 243
# 2      12085256                 229
# 3      12085257                 140
# 4      12085258                  63
# ...         ...                 ...
# 30603  12116287                 112
# 30604  12116288                 195
# 30605  12116289                 232
# 30606  12116290                 132
# 30607  12116291                 183
#
# [30608 rows x 2 columns]

# %%
display(pre_eip_txn_number)



fig = plt.figure()
ax = plt.axes()

#make lines that represent days
y1=np.linspace(0,600,10000)
x1=[5000 for x in range(len(y1))]

y2=np.linspace(0,600,10000)
x2=[10000 for x in range(len(y1))]

y3=np.linspace(0,600,10000)
x3=[15000 for x in range(len(y1))]

y4=np.linspace(0,600,10000)
x4=[20000 for x in range(len(y1))]

y5=np.linspace(0,600,10000)
x5=[25000 for x in range(len(y1))]

y6=np.linspace(0,600,10000)
x6=[30000 for x in range(len(y1))]



ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y',colors='white')
ax.title.set_color('white')
plt.plot(list(range(len(my_txn_number))),my_txn_number)
plt.plot(x1,y1,color='black')
plt.plot(x2,y2,color='black')
plt.plot(x3,y3,color='black')
plt.plot(x4,y4,color='black')
plt.plot(x5,y5,color='black')
plt.plot(x6,y6,color='black');
print(np.percentile(my_txn_number,5),np.percentile(my_txn_number,95))
# Out:
#          blocks  transaction_number
# 0      12085254                 131
# 1      12085255                 243
# 2      12085256                 229
# 3      12085257                 140
# 4      12085258                  63
# ...         ...                 ...
# 30603  12116287                 112
# 30604  12116288                 195
# 30605  12116289                 232
# 30606  12116290                 132
# 30607  12116291                 183
#
# [30608 rows x 2 columns]
# 118.0 315.0

# %% [markdown]
# now for post EIP
